# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.dates as mdates

# %%
inno_geocoded = pd.read_csv("inno_geocoded.csv")
# Out:
# /tmp/ipykernel_13536/646131400.py:1: DtypeWarning: Columns (53) have mixed types. Specify dtype option on import or set low_memory=False.
#   inno_geocoded = pd.read_csv("inno_geocoded.csv")

# %%
inno3 = inno_geocoded[inno_geocoded['inno_nr']=="inno_03"]
inno3
# Out:
#                       created_at           twitter_id     user_id  \
# 6748   2016-06-01 22:26:21+00:00   738134618818256897  4842357648
# 6751   2016-06-02 00:37:57+00:00   738167737038438400  2444029369
# 6752   2016-06-02 03:09:51+00:00   738205963941904384   236156250
# 6758   2016-06-09 17:38:23+00:00   740961252566925312  1216559311
# 6777   2016-06-10 15:25:58+00:00   741290316687253505    99823393
# ...                          ...                  ...         ...
# 20595  2019-12-05 03:41:31+00:00  1202432788957474817  1498879734
# 20610  2019-12-05 12:53:22+00:00  1202571666557227008   196299804
# 20621  2019-12-05 16:52:00+00:00  1202631720589246465   346872918
# 20623  2019-12-05 18:06:06+00:00  1202650368464826370  2222265067
# 20679  2019-12-06 19:26:43+00:00  1203033044174753792   334909293
#
#                                     user_location  longitude  latitude  \
# 6748                  ‹SQR› ‹KCR› ‹En tu corazón›        NaN       NaN
# ...

# %%
inno3["date"] = inno3['created_at'].astype('datetime64[ns]')
inno3.head()
# Out:
# /tmp/ipykernel_13536/2927655468.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inno3["date"] = inno3['created_at'].astype('datetime64[ns]')
#                      created_at          twitter_id     user_id  \
# 6748  2016-06-01 22:26:21+00:00  738134618818256897  4842357648
# 6751  2016-06-02 00:37:57+00:00  738167737038438400  2444029369
# 6752  2016-06-02 03:09:51+00:00  738205963941904384   236156250
# 6758  2016-06-09 17:38:23+00:00  740961252566925312  1216559311
# 6777  2016-06-10 15:25:58+00:00  741290316687253505    99823393
#
#                     user_location  longitude  latitude  place_box_1_long  \
# 6748  ‹SQR› ‹KCR› ‹En tu corazón›        NaN       NaN               NaN
# ...

# %%
inno3["day"] = inno3["date"].dt.date
# Out:
# /tmp/ipykernel_13536/853184141.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inno3["day"] = inno3["date"].dt.date

# %%
sns.set_style("whitegrid")
plt.figure(figsize = (15,8))
plt.xticks(rotation=90)
ax = sns.countplot(x="day", data=inno3, palette="Set3")


# Major ticks every half year, minor ticks every month,
ax.xaxis.set_major_locator(mdates.MonthLocator(bymonth=(1, 7)))
ax.xaxis.set_minor_locator(mdates.MonthLocator())


#ax.xaxis.set_major_formatter(ticker.FormatStrFormatter('%d'))
ax.xaxis.set_major_formatter(
    mdates.ConciseDateFormatter(ax.xaxis.get_major_locator()))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%b'))
for label in ax.get_xticklabels(which='major'):
    label.set(rotation=30, horizontalalignment='right')
ax.xaxis.set_major_locator(ticker.MultipleLocator(base=20))
plt.show()
